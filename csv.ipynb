# %%
import pandas as pd

# %%
service=pd.read_csv("hist_feature_v1 (1).csv")
service
# Out:
#         Unnamed: 0      user_id  sum  last
# 0                0  MKHEIM98094   79     5
# 1                1  BWGBSE89264   57     3
# 2                2  LHAWTZ43940  126     7
# 3                3  ERKCWP44285   73     5
# 4                4  VPCJHG63953   81     5
# 5                5  DVJFSJ41395   40     2
# 6                6  VNIKOF59264   50     3
# 7                7  BCODKW23723   80     5
# 8                8  RWCMTK12007   55     4
# 9                9  HLSZTB50403   84     5
# 10              10  WSSXGX93951   44     3
# 11              11  XACBTT43907   25     2
# 12              12  KXNISW70451   55     3
# 13              13  WKGDCU68097   70     5
# 14              14  QPEROT44185   43     2
# 15              15  VALFNY05267   83     6
# 16              16  USIMNT63953   31     2
# 17              17  YKPYMN52183   87     5
# 18              18  FCQNUE35187   50     3
# 19              19  AHQMPG75063   18     1
# 20              20  IYSBZQ82404  101     6
# ...
